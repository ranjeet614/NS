# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjeet614/NS/blob/main/NS_EXP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from cryptography.fernet import Fernet

message = "Ranjeet"

key = Fernet.generate_key()
cipher_suite = Fernet(key)

encMessage = cipher_suite.encrypt(message.encode())

print("Original Message:", message)
print("Encrypted Message:", encMessage)

decMessage = cipher_suite.decrypt(encMessage).decode()

print("Decrypted Message:", decMessage)
# Out:
# Original Message: Ranjeet
# Encrypted Message: b'gAAAAABqAiPRvkoq0U6aHFcIByIIQZHn75Kk0aTvdF48hq3wrb8dVgsnok9z9EvMKRjiwg-s2TqKBoyhxajir3NLL6ULpdgc7g=='
# Decrypted Message: Ranjeet
