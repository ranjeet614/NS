# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjeet614/NS/blob/main/Copy_of_NS_PR_4_Steganographyipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install stepic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.2/219.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stepic: filename=stepic-0.5.0-py3-none-any.whl size=12413 sha256=8fd0d65b326dabfe00c69d4a6255794dab68b91e7067241f14ec9b0b1cd8dc8c
#   Stored in directory: /root/.cache/pip/wheels/03/f1/06/0708209b0fc76adf88216a8133d7c7b0f084590a50a196a90c
# Successfully built stepic
# ...

# %%
# !pip install pillow stepic

# %%
from PIL import Image
import stepic


original_image = Image.open("/content/conor.jpg")
message = b'Ranjeet Shinde'
encoded_img = stepic.encode(original_image,message)
encoded_img.save('img2.png')
encoded_img.show()
decoded_msg= stepic.decode(encoded_img)
print(decoded_msg)
# Out:
# Ranjeet Shinde
